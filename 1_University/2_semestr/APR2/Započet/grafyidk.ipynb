# %%
from diktyonphi import Graph, GraphType, Edge, Node
from colorize import ColorGraph, colorize

g =ColorGraph(GraphType.UNDIRECTED)

g.add_node("A", {"color": None})
g.add_node("B", {"color": None})
g.add_node("C", {"color": None})
g.add_node("D", {"color": None})
g.add_node("E", {"color": None})
g.add_node("F", {"color": None})

g.add_edge("A", "B")
g.add_edge("A", "C")
g.add_edge("A", "D")
g.add_edge("A", "E")
g.add_edge("B", "C")
g.add_edge("B", "D")
g.add_edge("B", "E")
g.add_edge("C", "D")
g.add_edge("C", "E")
g.add_edge("E", "F")



colorize(g)
g
# Out:
# {'B', 'A', 'F', 'C', 'E', 'D'}
# B 0
# {'A', 'F', 'C', 'E', 'D'}
# A 1
# {'F', 'C', 'E', 'D'}
# C 2
# {'F', 'E', 'D'}
# E 3
# {'F', 'D'}
# D 3
# {'F'}
# F 0
# Graph(GraphType.UNDIRECTED, nodes: 6, edges: 10)
